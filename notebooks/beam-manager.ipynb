# %%
# %load_ext beam.setup
# Out:
# Setting up the Beam environment for interactive use
# Standard modules will be automatically imported so you can use them without explicit import
# Beam library is loaded from path: /home/dayosupp/projects/beamds/beam
# 🔥 | 15:40:50 (0:00:01.622807) | INFO     🗎 Beam logger (version 2.6.10): logs are saved in /tmp/.beam/ipykernel_launcher-20240905-154050.log (∫__init__.py:__getattr__-#144)
# Done importing packages. It took:  2.0 seconds

# %%
manager=resource("http://api-35000-beam-manager-j28pr-starfield.apps.kh-dev.dt.local")

# %%
from beam.orchestration import ServeClusterConfig

# %%
from beam.orchestration import RnDClusterConfig

# %%
config = RnDClusterConfig('/home/dayosupp/projects/beamds/examples/orchestration_beamdemo.yaml')

# %%
config = RnDClusterConfig('/home/dayosupp/projects/beamds/examples/orchestration_beamdemo.yaml')

# %%
manager. (config)
# Out:
# 🔥 | 17:14:17 (1:33:28.721435) | ERROR    🗎 Error in get request: (code:504) (∫http_client.py:_post-#46)
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 manager.launch_rnd_cluster(config)
#
# File /home/dayosupp/projects/beamds/notebooks/../beam/serve/client.py:111, in BeamClient._create_function_with_signature.<locals>.new_func(*args, **kwargs)
#     110 def new_func(*args, **kwargs):
# --> 111     return func(*args, **kwargs)
#
# File /home/dayosupp/projects/beamds/notebooks/../beam/serve/client.py:68, in BeamClient.post(self, path, *args, **kwargs)
#      65 self.dump_function(kwargs, io_kwargs)
#      66 io_kwargs.seek(0)
# ---> 68 response = self._post(path, io_args, io_kwargs)
#      70 return response
#
# ...

# %%
manager.info
# Out:
# {'attributes': {'beam_class_name': {'description': None,
#    'name': 'beam_class_name',
#    'signature': None,
#    'type': 'property'},
#   'clear_cache': {'description': None,
#    'name': 'clear_cache',
#    'signature': {'parameters': [{'annotation': None,
#       'default': None,
#       'kind': 'VAR_POSITIONAL',
#       'name': 'args'}],
#     'return_annotation': None},
#    'type': 'method'},
#   'cluster_info': {'description': None,
#    'name': 'cluster_info',
#    'signature': {'parameters': [{'annotation': None,
#       'default': None,
#       'kind': 'POSITIONAL_OR_KEYWORD',
#       'name': 'cluster'}],
#     'return_annotation': None},
#    'type': 'method'},
#   'clusters': {'description': None,
#    'name': 'clusters',
#    'signature': None,
#    'type': 'variable'},
#   'get_cluster_name': {'description': None,
#    'name': 'get_cluster_name',
#    'signature': {'parameters': [{'annotation': None,
#       'default': None,
#       'kind': 'POSITIONAL_OR_KEYWORD',
# ...

# %%
manager.launch_ray_cluster(conf)
# Out:
# {'attributes': {'beam_class_name': {'description': None,
#    'name': 'beam_class_name',
#    'signature': None,
#    'type': 'property'},
#   'clear_cache': {'description': None,
#    'name': 'clear_cache',
#    'signature': {'parameters': [{'annotation': None,
#       'default': None,
#       'kind': 'VAR_POSITIONAL',
#       'name': 'args'}],
#     'return_annotation': None},
#    'type': 'method'},
#   'cluster_info': {'description': None,
#    'name': 'cluster_info',
#    'signature': {'parameters': [{'annotation': None,
#       'default': None,
#       'kind': 'POSITIONAL_OR_KEYWORD',
#       'name': 'cluster'}],
#     'return_annotation': None},
#    'type': 'method'},
#   'clusters': {'description': None,
#    'name': 'clusters',
#    'signature': None,
#    'type': 'variable'},
#   'get_cluster_name': {'description': None,
#    'name': 'get_cluster_name',
#    'signature': {'parameters': [{'annotation': None,
#       'default': None,
#       'kind': 'POSITIONAL_OR_KEYWORD',
# ...
