# %%
from beam import resource

# %%
alg = resource('http://flask-35000-university-zxr9q-kh-dev.apps.kh-dev.dt.local')

# %%
image = resource('road-ahead-cars-n-bikes.jpg').read()

# %%
alg.process(image)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=845x440>

# %%
image
